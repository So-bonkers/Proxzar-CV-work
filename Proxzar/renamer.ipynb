# %%
import os
import pandas as pd

# %%
dataset_path = "/home/sklaptop/Downloads/Aug_images/P25 - Visual Search/Augmented images/"

# %%
categories =[]
subtypes=[]
fileid=[]
filenames =[]

# %%
for filename in os.listdir(dataset_path):
    if filename.endswith(".jpg"):
        file_parts = filename.split("_")
        if len(file_parts) >=2:
            category = file_parts[0]
            subtype = file_parts[1]
            fileids = file_parts[2]
            fileid.append(fileids)
            subtypes.append(subtype)
            categories.append(category)
            filenames.append(filename)

# %%
fileid = [fileid.replace(".jpg", "") for fileid in fileid]
fileid
# Out:
# ['atlasroofing17x4x8polyisoroofinsulation',
#  'basfmastersealsl2slopegrade15gallonpail',
#  'hunterpanels175x4x8hshieldgradeii20psipolyisoinsulationwithfiberreinforcedfacers',
#  'certainteedvinylbuildingproducts412x200certawraphousewraprollweatherresistantbarrier',
#  'qualityedge019x2x3x4brickledgejumperwhite280',
#  'rockwool2x16x48cavityrock64sqftbag',
#  'certainteedinsulation312x2314x93sustainabler11unfacedbatts23767sqftperbag',
#  'atasmetals5guttersplice',
#  'carlislecoatingswaterproofing6x100ccw705ltlowtempairvaporbarrierstrips',
#  'universalpolymerscorporationupc20highliftclosedcellsprayfoampartaregulargrade500lbdrum',
#  'genflex425x4x8polyisoinsulation',
#  'gmc40x49gmcraft60doubleweatherresistivebarrier162sqftroll',
#  'siplast12x4x4densdeckprimed',
#  'mastic3x4stylea75degreeelbowblack',
#  'henrycompany93018polymermodifiedadhesive45gallonpailgreen',
#  'bergerbuildingproductsflexaspoutgreen',
#  'englert6canadianbarhanger',
#  'insulationcorporation114x9x8epsflutefiller1lbdensity',
#  'owenscorning24x96r21bu110ecotouchpinkfiberglasunfacedbattinsulationwithpurefibertechnology112sqftbag',
#  'carlislecoatingswaterproofing4x50miradrain2000drainagecomposite',
#  'rockwool24x47comfortbattr30oc3003sqftbag',
#  'fiberlitetechnologiesrplusstabilizedcelluloseinsulation',
#  'remay178x165typarconstructiontape',
#  'bergerbuildingproducts16oz5halfroundcopperbstyleoutlet',
#  'qualityedge5guttergekkoinsidemiter',
#  'rockwool112x2x48cavityrockbagof8',
#  'gafolybond500insulationadhesivepart2regulargrade5gallonpail',
#  'carlislesyntec124x8densdeckprimeroofboard',
#  'englert5aluminuminsidestripmitereggshell',
#  'bergerbuildingproducts26gauge6x20halfroundgalvanizedsteelguttersinglebead',
#  'henrycompany4x75blueskinbutylflashselfadheredflashingwhite',
#  'bergerbuildingproducts26gauge6x10plainroundpaintgripsteeldownspout',
#  'usaluminum5heavydutyhiddenhangerboxof100',
#  'johnsmanville31215x32comfortthermpolywrappedfiberglassrollinsulation40sqftroll',
#  'wrmeadows20milx4x160perminatorevohgasbarriertape',
#  'bergerbuildingproducts640kpaintedaluminumfasciahangerwithsnapstraphighglosswhite',
#  'klauermanufacturingcompany5x10kgutterstandardgaugewhite',
#  'basfmastersealp2552partprimerkit34gallonpail',
#  'owenscorning2x2x4fiberglas705frkfacedinsulationboard48sqftbox',
#  'bergerbuildingproducts26gauge5x26kstylegalvanizedsteelgutterstraightback',
#  'basfmastersealnp125sealantadhesive10ozplasticcartridgeclear',
#  'siplast235x4x4isopanel',
#  'bergerbuildingproducts6x20halfroundcoppergutter',
#  'owenscorning15x48r19w68qecotouchpinkfiberglasunfacedbattinsulationwithpurefibertechnology80sqftbag',
#  'carlislesyntec254x4securshieldhdcomposite25psipolyisoinsulationwith12hdpolyisocoverboard',
#  'bergerbuildingproducts16oz5x3halfroundcopperendpiece',
#  'versico14x8securshieldgradeii20psipolyisoinsulation',
#  'blueridgefiberboard5x4x4cantstrips72bundle',
#  'bergerbuildingproducts016x2x3squarecorrugatedastylemillfinishaluminum75elbow',
#  'basfmastersealnp1sealant20ozpropakgrey',
#  'hunterpanels2x4x8hshieldhdcompositecgpolyisoinsulation',
#  'frostking6x20plasticmeshgutterguardblack',
#  'usaluminum3x4rectangularoutlet',
#  'carlislecoatingswaterproofingfireresistbarritechvp50gallondrum',
#  'spectrametalsales4roundelbowblack',
#  'rockwool3x1514x47safensound5973sqftbag',
#  'bergerbuildingproducts26gauge3x10roundcorrugatedpaintgripsteeldownspout',
#  'thermall34x6x102reflectrpskinsulation',
#  'tremco24x75exoair110at',
#  'hunterpanels36x4x8hshieldgradeii20psipolyisoinsulationwithfiberreinforcedfacers',
#  'hunterpanels34x4x8hshieldcgcoatedglassfacergradeiii25psipolyisoinsulation',
#  'graco14x102000psiheatedwhiphosewithscuffguard',
#  'alldeckenviromentalcoatingsystemsglassmat50sqft',
#  'tremco36x75exoair110',
#  'bergerbuildingproducts16oz4x5x10squarecorrugatedcopperdownspout',
#  'lapollaindustriesfoamlok20004gclosedcellsprayinsulationpartasummergrade500lbdrum',
#  'berryplastics3x100typarbuildingwrap',
#  'bergerbuildingproducts16oz3x4squarecorrugatedastylecopper45elbow',
#  'raytec6aluminumhangtitehiddenhangerwithoutclipcartonof1000',
#  'wrmeadows20milx4x160perminatorevohgasbarriertape',
#  'henrycompany12x100blueskinvp100selfadheredwaterresistiveairbarriermembraneblue',
#  'johnsmanville61415x48comfortthermpolywrappedunderfloorfiberglassbattinsulation90sqftbag',
#  'bergerbuildingproducts6kstyleoutsidecopper90stripmiter',
#  'awardmetals13x10aluminumraindiverter',
#  'rmaxc2to25tapered4x4polyisoinsulationpanel',
#  'bergerbuildingproducts26gauge6x20kstylegalvanizedsteelgutterstraightback',
#  'versico34x8nailboard',
#  'cetco4coredisc',
#  'carlislecoatingswaterproofingmiraseal5gallonpailblack',
#  'bergerbuildingproducts16oz5halfroundcopperbstyleoutlet',
#  'owenscorning512x15x47thermafiberultrabattmineralwoolinsulation2448sqftbag',
#  'owenscorning2x16x48thermafiberrainbarrier45continuousmineralwoolinsulation',
#  'versico254x8versicoremphgradeii20psipolyisoinsulation',
#  'gcpappliedtechnologies36x75vycorplusblackgrey',
#  'spectrametalsales6insidestripmiterdarkbronze',
#  'carlislecoatingswaterproofing12x100miradrainhcdrainagecompositenonpunchedroll',
#  'lambritchie4aluminumornamentalconductorbandwhite',
#  'alscometals3x4aluminumledgejumpermusketbrown',
#  'bergerbuildingproducts16oz6halfroundcopperbstyleoutlet',
#  'bergerbuildingproducts16oz5kstylerightcopperendcap',
#  'certainteedroofing1x4x8grade220psipolyiso',
#  'carlislecoatingswaterproofing4x100fireresist705fraairvaporbarrier',
#  'certainteedinsulation814x23x48sustainabler30cathedralceilingkraftfacedbatts7667sqftperbag',
#  'dimensionalmetals24gaugex7rollformedgutter',
#  'variformbyplygempipebandcopper',
#  'englert032x15guttercoilsoldperlinft',
#  'carlislecoatingswaterproofing12miradrainhcsideoutconnector',
#  'carlislecoatingswaterproofing6x300liquifiber',
#  'continentalmaterials112x18taperededgefiberboard32linftbundle',
#  'cantproducts112x24perlitetaperededge24linftbundlelightgrey',
#  'gracot1transferpump21ratio',
#  'gracopolycarballoysidesealpackof50',
#  'graco10lp2000psiimprovedflexwhiphosewith14insidediameter',
#  'rmax1x4x10thermasheath3foilfacedpolyisoinsulation',
#  'georgiapacific12x4x12toughrockgypsumboard',
#  'fiberlitetechnologiesfiberlitepluscelluloseinsulation',
#  'rmax1x2x8tsx8500polyisoinsulation',
#  'bergerbuildingproducts16oz4plainroundcopper75elbow',
#  'mastic6leafreliefinsidecorner',
#  'owenscorning15x48r24bu108ecotouchpinkfiberglasunfacedbattinsulationwithpurefibertechnology35sqftbag',
#  'gcpappliedtechnologies18x75permabarrierwallflashing',
#  'carlislecoatingswaterproofing24x100ccw705ltlowtempairvaporbarrier',
#  'johnsmanville3121514x105tablesskraftfacedfiberglassbattinsulation12231sqftbag',
#  'atlasroofing2x4x8energyshieldpro2continuouswallinsulation',
#  'rheinzink5crchalfroundrightendcap',
#  'owenscorning16x48r19m82ecotouchpinkfiberglasunfacedbattinsulationwithpurefibertechnology8533sqftbag',
#  'sikay112to212tapered4x4sarnathermpolyisoinsulation',
#  'hunterpanelse3to35taperedhshield4x4gradeii20psifiberreinforcedfacerpolyisoinsulation',
#  'cantproducts112x18taperededge32linftbundle',
#  'hunterpanels25x4x8hshieldcgcoatedglassfacergradeiii25psipolyisoinsulation',
#  'bergerbuildingproducts16oz2x3squarecorrugatedcopper5offsets',
#  'gafolybond500greeninsulationadhesivepart15gallonbaginbox',
#  'bergerbuildingproducts5kstyleinsidecopper90stripmiter',
#  'bergerbuildingproducts16oz6kstyleleftcopperendcap',
#  'houstonfoamplastics12x4x50fanfoldepsinsulation125lbdensity2sqbundle',
#  'henrycompanyairbloc17mrairbarriermembrane5gallonpailgraphite',
#  'siplast235x4x4isogradeiii25psiinsulation',
#  'tremcotremproof250gcrollergrade5gallonpailblack',
#  'bergerbuildingproducts4roundgalvanizedsteelsicklehookforwood',
#  'bergerbuildingproducts6x4kstyletitanguardaluminumflatgutterguardmillfinish',
#  'polyglasspolypufisocyanateforpolypuffoamsystemparta50gallondrum',
#  'hunterpanels39x4x8hshieldgradeiii25psipolyisoinsulationwithfiberreinforcedfacers',
#  'fomoproductshandifoamextremegunfoam24ozcan',
#  'internationalbildrite12x2x4highdensityfiberboard',
#  'touchnsealguntipwithbrass',
#  'bergerbuildingproducts4halfroundpaintedaluminumwideflangebstyleoutletroyalbrown',
#  'graco50fluidtemperaturesensorrtdcable4pin',
#  'gracoproblerp2sealhousing',
#  'cetco4x75aquadraing20subsurfacedrainagecomposite',
#  'dupont10x125tyvekdrainwrap',
#  'henrycompanyaquatacprimeremulsionprimerforselfadheredmembranes5gallonpailaqua',
#  'qualityedge027x1178x150aluminumminiguttercoilwhite280',
#  'usgypsum38x4x8securockgypsumfiberroofboard',
#  'owenscorning614x15x94r19e59ecotouchpinkfiberglaskraftfacedrolledbattinsulationwithpurefibertechnology4896sqftroll',
#  'rheinzink5halfroundfasciahanger',
#  'tremco60milx4x75parasealpermanentseamtape',
#  'bergerbuildingproducts032x7x10halfroundpaintedaluminumguttersinglebeadhighglosswhite',
#  'rheinzink360plainroundelbow',
#  'bergerbuildingproducts18oz6euracraftleftcopperquarterballendcapwith2gutter',
#  'bergerbuildingproducts20oz8x25kstylecoppergutterstraightback',
#  'rmax2x4x4multimaxfaabovethedeckpolyisoinsulation',
#  'carlislecoatingswaterproofingbarricoatsspraygrade55gallondrumdarkbrownblack',
#  'bergerbuildingproducts28gauge4x5x10squarecorrugatedpaintedgalvanizedsteeldownspoutbrown',
#  'performanceroofsystems3x312tapered4x4isoepanel',
#  'atlasroofingaa12to1taperedacfoamiii4x4gradeiii25psipolyisocgfroofinsulation',
#  'alscometals5aluminumoutsideboxmitergrey',
#  'dow9x100weathermatehousewrapwhite',
#  'bergerbuildingproducts024x4x5x10squarecorrugatedmillfinishaluminumdownspout',
#  'johnsmanvillee3to354x4taperedenrgy3gradeii20psipolyisoroofinsulation',
#  'blueridgefiberboard1x4x4structodekhdfiberboardwith6sidecoating',
#  'variformbyplygem2x3stylepremium30aelbowterratone',
#  'johnsmanville124x8retroplusroofboard',
#  'hunterpanels15x4x8hshieldffoilfacedpolyisoinsulation',
#  'bergerbuildingproducts31copperpipecleat',
#  'benjaminobdyke5x100hydrogapdrainablehousewrap',
#  'basfmasterseal614coldappliedwaterbasedcoating5gallonpail',
#  'cetcocorner',
#  'englert2x3x10019gaugealuminumdownspoutmusketbrown',
#  'klauermanufacturingcompany15x150classicsteelminiguttercoileggshell',
#  'atasmetals3x4dropoutlet',
#  'gracoreactore20proportionerpackagefusionapgunheatedhosewithscuffguard230v1ph',
#  'artssheetmetal6roundpitchpocket',
#  'qualityedge024x1312x61truguardaluminumgutterprotectionpanelonlyterratone',
#  'carlislecoatingswaterproofingmiradri860selfadheringwaterproofingmembrane2sqrolldarkgrey',
#  'performanceroofsystems12to1tapered4x4isoaapanel',
#  'carlislecoatingswaterproofing500reinforcingfabric20sqroll',
#  'mastic6guttercoilsoldperlinftwhite',
#  'enduroproducts2x9galvanizedmetallath25lbspersqyd',
#  'bergerbuildingproducts16oz3x10plainroundfreedomgraycopperdownspout',
#  'firestonebuildingproducts154x4resistagradeii20psipolyisoinsulation',
#  'graco58cleanoutdrillbitcleanoutkit',
#  'gracofusionpcretrofitkitwith01mixchamber3cartridges',
#  'bergerbuildingproducts26gauge5x10halfroundgalvanizedsteelguttersinglebead',
#  'bergerbuildingproducts032x6x20kstylepaintedaluminumgutterapron90darkbronze',
#  'sikaa1to112tapered4x4sarnathermpolyisoinsulation',
#  'bergerbuildingproductsbrassrodnutsforcopperregalbarhanger',
#  'bergerbuildingproducts5roundgalvanizedsteelwirestrainer',
#  'bergerbuildingproducts26gauge6halfroundgalvanizedsteelslipjoint',
#  'bergerbuildingproducts032x7x25kstylepaintedaluminumgutterstraightbackhighglosswhite',
#  'clendeninbros7x14aluminumgutterspikewhite',
#  'tremco4x50tremdraintreatedgsdrainagemat12core',
#  'apoc12x4x8protectionpanel',
#  'mastic27milx6x15guttercoilsoldbythelbwicker',
#  'atlasroofing1x4x8acfoamiiigradeii20psipolyisocgfroofinsulation',
#  'dupont5x200tyvekstuccowrap',
#  'wrmeadows12x5x10fibreexpansionjoint',
#  'qualityedge5insidestripmitrewhite515',
#  'tribuilt6x3kstyledropinmillfinishaluminumgutterguard',
#  'rollex2x3x10downspoutbronze',
#  'wrmeadows12x4x10fiberexpansionjoint',
#  'tamko18x61tw60selfadheringsheetwaterproofingmembranewintergrade',
#  'bergerbuildingproducts032x5x32kstylepaintedaluminumgutterhembackroyalbrown',
#  'cetcoxpwaterstop157linftperbox',
#  'convenienceproductssharpshooterxfoamgun',
#  'gracofusionairpurgequickchangefronthalfsprayheadkit',
#  'carlislecoatingswaterproofing704rubberizedbitumenmastictubes',
#  'hunterpanels26x4x8xcicgcoatedglassfacerpolyisoinsulation',
#  'carlislecoatingswaterproofing4x50miradrain9000drainagecomposite',
#  'mazenails131x310dgundoublehotdipgalvanizedringshanknailsforplywood',
#  'owenscorning5x15x48thermafibersafbmineralwoolinsulation30sqftbag',
#  'basfmastersealnp1sealant20ozpropakgrey',
#  'bergerbuildingproducts027x1134x1505kpaintedaluminumgutterminicoilampdarkbronze',
#  'siplast3x4x8isopanel',
#  'gcpappliedtechnologies4x50hydroduct660',
#  'bergerbuildingproducts019x3x4squarecorrugatedbstylepaintedaluminum90elbowroyalbrown',
#  'hunterpanels35x4x8hshieldnbpolyisoinsulationwithfiberreinforcedfacer',
#  'blueridgefiberboard0x12taperededgestrips48bundle',
#  'bergerbuildingproducts26gauge2x3squarecorrugatedastylegalvanizedsteel75elbow',
#  'roofguardiantechnologiesheatblocultratwopartkit',
#  'hunterpanelsq05to25taperedhshieldgradeiii25psipolyisoinsulationwithfiberreinforcedfacers',
#  'westcoatspecialtycoatingsystemstc0microcement45lbbaggrey',
#  'awardmetals28gauge134x23490styleaelbow',
#  'gcpappliedtechnologies9x75vycorbutyl',
#  'performanceroofsystems312x412tapered4x4isozzpanel',
#  'johnsmanville124x4separatorpolyisoroofrecoverboard',
#  'lyftymbuildingproducts3x4stylea75elbowcharcoalgrey',
#  'carlislecoatingswaterproofingfireresistbarritechvp50gallondrum',
#  'bergerbuildingproducts26gauge4x5squarecorrugatedastylegalvanizedsteel75elbow',
#  'rheinzink4plainroundleafcollector',
#  'bergerbuildingproducts6kstylemillfinishaluminumheavydutyhiddenhangerforstraightbackorhembackgutter',
#  'bergerbuildingproducts6x3kstyleexposedmetaldropincoppergutterguard',
#  'remay5x100typardrainablewrap',
#  'cantproducts1x4woodfibercant96linftbundle',
#  'atlasroofing27x4x8polyisoroofinsulation',
#  'atlasroofing15x4x4acfoamiigradeiii25psipolyisogrfroofinsulation',
#  'bergerbuildingproductsmillfinishaluminumrodnutsforaluminumregalbarhanger',
#  'kingspaninsulation4x100greenguardbutylflashingtape',
#  'hunterpanelse3to35taperedhshield4x4gradeii20psifiberreinforcedfacerpolyisoinsulation',
#  'fibertiteseaman3x4x8iso',
#  'gracofusionairpurgegreasegun',
#  'henrycompany138x164aquablocpumafleecereinforcementfabric',
#  'basfmasterprotecthb400waterproofcoatingfinemedium5gallonpail',
#  'bergerbuildingproducts032x6x27halfroundsinglebeadpaintedaluminumgutterroyalbrown',
#  'hunterpanels24x4x8hshieldgradeii20psipolyisoinsulationwithfiberreinforcedfacers',
#  'raytec234roundoutletmill',
#  'cetco8corecaptieback',
#  'owenscorning15x94r13e14ecotouchpinkfiberglaskraftfacedrolledbattinsulationwithpurefibertechnology8812sqftroll',
#  'coselladorkenproducts8x656deltadrainmembrane527sqftrollchocolatebrowngrey',
#  'bergerbuildingproducts16oz5x10kstylecoppergutterstraightback',
#  'bergerbuildingproducts634coppershankextension',
#  'atasmetals7hiddenhanger',
#  'edcoproducts2x3aluminumubanddownspoutentexfinishhartfordgreen',
#  'cetco1438holeabandonmentmediumchip50lbbag',
#  'gracofusionairpurgegreasefitting',
#  'bergerbuildingproducts26gauge6x30halfroundgalvanizedsteelguttersinglebead',
#  'cetco36x67rap400sa',
#  'bergerbuildingproducts6roundgalvanizedsteelwirestrainer',
#  'raindropgutterguardsystems5extremevalley',
#  'atlasroofing3x4x8polyisoroofinsulation',
#  'owenscorning2x24x48thermafiberfirespan90unfacedmineralwoolinsulation64sqftbag',
#  'spectrametalsales6leftendcapdovegrey',
#  'continentalmaterials12x4x4highdensityfiberboardgp',
#  'atlasroofing2x4x8acfoamiiigradeii20psipolyisocgfroofinsulation',
#  'owenscorning312x15x105r15k97ecotouchpropinkfastbattfiberglaskraftfacedbattinsulationwithpurefibertechnology8750sqftbag',
#  'certainteedinsulation312x16x96r13unfacedbatts13867sqftperbag',
#  'hunterpanels3x4x8hshieldnbpolyisoinsulationwithfiberreinforcedfacer',
#  'bergerbuildingproducts024x4plainroundpaintedaluminum90elbowdarkbronze',
#  'cetcobentogroutinjectionpacker',
#  'johnsmanville31215x32comfortthermpolywrappedfiberglassrollinsulation40sqftroll',
#  'hunterpanels21x4x8hshieldnb58plywoodfiberreinforcedfacerpolyisoinsulation',
#  'hunterpanels2x4x8xcicgcoatedglassfacerpolyisoinsulation',
#  'bergerbuildingproducts16oz2x3squarecorrugatedcopper2offsets',
#  'mastic3x4stylea75degreeelbowblack',
#  'allstarfoammarketingc21to2taperedfoameps4x4insulationpanel1density',
#  'bergerbuildingproducts26gauge3roundcorrugatedgalvanizedsteel60elbow',
#  'bergerbuildingproducts032x7x20kstylepaintedaluminumgutterstraightbackhighglosswhite',
#  'kingspaninsulation4x66butyltape',
#  'sika58x4x4densdeckprimeroofboard',
#  'soprema84mil394x492colphene180sanded15sqroll',
#  'englert032x15guttercoilsoldperlinft',
#  'carlislecoatingswaterproofingmiradri860selfadheringwaterproofingmembrane2sqrolldarkgrey',
#  'alscometals2x3x10aluminumdownspoutmusketbrown',
#  'bergerbuildingproducts16oz4plainroundfreedomgraycopper75elbow',
#  'tremco12x75exoair110',
#  'jrproductsir100purainsulationreleasespray1025ozspraycan',
#  'fibertiteseaman2x4x8iso',
#  'hunterpanelsg1to2tapered8x8hingedtargetdrainsumpwith14slope',
#  'atlasroofing12x4x4acfoamrecoverboardinsulation',
#  'hunterpanelsc2to25taperedhshield4x4gradeii20psifiberreinforcedfacerpolyisoinsulation',
#  'gacowesterngacoonepassregularpartb55gallondrum',
#  'qualityaluminumproducts6insidestriplowglosswhite',
#  'continentalmaterials1x4x86sidedfiberboard',
#  'gracofusionproconnectretrofitkitwith02mixchamber3cartridges',
#  'napco5x10classicleafrelief',
#  'bergerbuildingproducts18oz4x984euracraftcoppersmoothroundweldeddownspout',
#  'lambritchie5rightendcapwhite',
#  'bergerbuildingproducts5x3kstyledropincoppergutterguard',
#  'cmg26gauge2x4gutterapronbonewhite',
#  'mastic32milx6seamlessguttersoldperlinftevergreen',
#  'graco296907roundportkitmodule1',
#  'henrycompany4x164aquablocpumafleecereinforcementfabric',
#  'remay5x100typardrainablewrap',
#  'certainteedinsulation312x15x93sustainabler15kraftfacedbatts7750sqftperbag',
#  'gaf124x8structodekhighdensityfiberboardroofinsulationcoverboardwithprimedredcoating1sidecoated',
#  'graco58x024odspring',
#  'internationalbildrite12x2x4highdensityfiberboard',
#  'siplast2x4x8isopanel',
#  'convenienceproductssharpshooter46foamgun',
#  'edcoproducts032x1178aluminumguttercoilentexfinishstatuarybronze',
#  'alscometals5aluminuminsidestripmiterterratone',
#  'odeproducts5hangerwithscrewnoclip',
#  'bergerbuildingproducts234roundsnapintubeoutletmillfinish',
#  'wrmeadows6x6212melrolselfadheringwaterproofingmembrane',
#  'bergerbuildingproducts3copperdownspouttube',
#  'owenscorning614x23x392r19ru41ecotouchpinkfiberglasunfacedrollinsulationwithpurefibertechnology7507sqftroll',
#  'johnsmanville11224x48unfacedmineralwoolsoundfireblockbatt112sqftbag',
#  'rmax12x4x8ecomaxcipolyisoinsulationpanel',
#  'bergerbuildingproducts125x6kstylemillfinishaluminumcustomcrossbarhanger',
#  'bergerbuildingproducts26gauge5plainroundgalvanizedsteel45elbow',
#  'westcoatspecialtycoatingsystemsec34epoxytopcoatpartb5gallonpailcapecodgrey',
#  'usaluminum6speedscrewhangerwithoutclip',
#  'basfmastersealnp100highperformancehybridsealant20ozpropakstone',
#  'atasmetals032x1175x200aluminumguttercoil',
#  'hunterpanels3x16x8xcifoilfacerpolyisoinsulation',
#  'bergerbuildingproducts26gauge5halfroundinsidepaintgripsteel90miter',
#  'gracofusionproconnectretrofitkitwith0102mixchamber3cartridges',
#  'johnsmanville144x4invinsafrncefoamcore',
#  'cetcowaterstoppage50lbbag',
#  'basfmastersealsl2selfleveling15gallonpaillimestone',
#  'convenienceproductsseries2machine',
#  'owenscorning1x24x48thermafiberfirespan90plainmineralwoolinsulation64sqftbag',
#  'tamkotwm1rubberizedbitumenmastic3gallonpailblack',
#  'hunterpanels45x4x8hshieldnbpolyisoinsulationwith716osbandfiberreinforcedfacer',
#  'wrmeadows12x48x10fibreexpansionjointsheet',
#  'lambritchie43galvanizedroundcorrugatedelbow',
#  'dimensionalmetalsdownspoutstrap',
#  'usaluminum5aluminumhiddenhangermill',
#  'dimensionalmetalsdownspoutelbow',
#  'usaluminum3x4rectangularoutlet',
#  'fortifiber40x72superjumbotex60minutegradedweatherresistivebarrier240sqft',
#  'bergerbuildingproducts16oz6halfroundinsidefreedomgraycopper90miter',
#  'bergerbuildingproducts6kstylemillfinishaluminumhiddenhangerwithscrewforstraightbackgutter',
#  'hunterpanels15x4x8hshieldnbpolyisoinsulationwithfiberreinforcedfacer',
#  'lowereflectiveinsulation732coolthermasheet',
#  'spectrametalsales4x5x10downspout30degreewhite',
#  'usaluminum5aluminumhiddenhangermill',
#  'edcoproducts3x4aluminumastyleelbowentexfinishroyalbrown',
#  'hunterpanelsx05to15taperedhshieldcg4x4coatedglassfacergradeii20psipolyisoinsulation',
#  'graco18fusionairpurgeairhose',
#  'continentalmaterials12x4x4highdensityfiberboardgp',
#  'universalpolymerscorporationupc20highliftclosedcellsprayfoampartbwintergrade500lbdrum',
#  'carlislesyntec44x4securshieldgradeiii25psipolyisoinsulation',
#  'lambritchiepoprivetspackof1000brown',
#  'bergerbuildingproducts16oz4plainroundcopper90elbow',
#  'bergerbuildingproducts18oz3110euracraftcopperswanneckoffset',
#  'insulationcorporation112x812x8epsflutefiller',
#  'spectrametalsales6stainlesssteelrightendcaplinen',
#  'henrycompanyairbloc32mrairwatervaporbarriermembrane5gallonpailbeige',
#  'henrycompany6x75blueskinwb25windowdoorflashingblue',
#  'carlislecoatingswaterproofing12x100ccw705twfthruwallflashing',
#  'atlasroofing25x4x8acfoamiigradeii20psipolyisoroofinsulation',
#  'owenscorning112x48x100type75softrductwrapfrkfiberglassinsulation',
#  'owenscorningthermafiberimpasselockingwashers',
#  'bergerbuildingproductspaintedaluminumrackkeyroyalbrown',
#  'bergerbuildingproducts16oz5x10halfroundcopperguttersinglebead',
#  'tremco9x75exoair110at',
#  'bergerbuildingproducts032x5kstylepaintedaluminuminsidemiterbrown',
#  'gracolowpressureairgaugebottommount0100psipressurerange',
#  'gcpappliedtechnologies9x667bituthene3000membranedarkgreyblack',
#  'owenscorning912x24x48r30f10ecotouchpinkfiberglasfoilfacedbattinsulationwithpurefibertechnology80sqftbag',
#  'masticdownspoutclipfor3x4downspoutsandtone',
#  'fortifiber6x50fortiflexbutylwaterproofflashingmembrane',
#  'usaluminum6doubleribhangerwithclipsoldperpiece',
#  'vaproshield59x164wrapshieldsamembraneorange',
#  'westcoatspecialtycoatingsystemsec11waterbasedepoxypartaonly5gallonpailcapecodgrey',
#  'usgypsum58x4x4securockcementboard',
#  'bergerbuildingproducts3galvanizedsteeldownspouttube',
#  'hunterpanels25x4x4hshieldcgcoatedglassfacerpolyisoinsulation',
#  'polyglasspolypufrgisocyanateforpolypuffoamsystemparta50gallondrum',
#  'bergerbuildingproducts032x6x30halfroundmillfinishaluminumguttersinglebead',
#  'dennybuildingproducts9x150housewrap',
#  'rockwool35x2x4afbbattinsulation64sqftbag',
#  'unitedasphaltnewjersey112x24perlitetaperededge48bundle',
#  'bergerbuildingproducts6kstyleoutsidepaintedaluminum90stripmiterblack',
#  'soprema24mil374x984soprasealstickvp3sqroll',
#  'convenienceproducts30hose',
#  'mastic2x3stylearectangular75degreeelbowdesertsand',
#  'bergerbuildingproducts4squaresteelsicklehookbrown',
#  'carlislecoatingswaterproofing36x75ccw705twfthruwallflashing',
#  'alscometals027x1178guttertuffguttercoilsoldperlbcolonialivory',
#  'variformbyplygem027x1134aluminumguttercoilfor5seamlessguttershighglosswhite',
#  'bergerbuildingproducts5kstylerightpaintedaluminumendcapterrabronze',
#  'performanceroofsystems1to112taperedisoapanelca',
#  'qualityedge019x2x3rectangularoutletmillfinish',
#  'bergerbuildingproducts3x16closedcoppereavebox',
#  'gracofusionairpurgeh30reactor2eliteproportioner',
#  'bergerbuildingproducts26gauge4plainroundgalvanizedsteel45elbow',
#  'hunterpanels45x4x8xcifoilfacerpolyisoinsulation',
#  'gaf124x4structodekhighdensityfiberboardroofinsulationcoverboardwithprimedredcoating6sidecoated',
#  'rockwool3x2x4cavityrockbag',
#  'derbigum1x4x4derbiboardisocapolyisocyanurateroofinsulationboard',
#  'lapollaindustriesfoamlok20004gclosedcellsprayinsulationpartaregulargrade500lbdrum',
#  'carlislecoatingswaterproofing18x100fireresist705fraairvaporbarrier',
#  'bergerbuildingproducts26gauge6x25halfroundgalvanizedsteelguttersinglebead',
#  'bergerbuildingproducts16oz5x30kstylecoppergutterstraightback',
#  'carlislecoatingswaterproofing4x50miraplyvverticalgradewaterproofingmembrane',
#  'roofguardiantechnologiesheatblocultratwopartkit',
#  'hunterpanels37x4x8xcinbverticalnailablepolyisoinsulationwithcgfand34plywood',
#  'firestonebuildingproducts054x4isogardhdgradei80psicoverboard',
#  'gracoswivelunionassembly',
#  'hunterpanels32x4x8hshieldnb34plywoodfiberreinforcedfacerpolyisoinsulation',
#  'johnsmanville314x4enrgy3gradeii20psipolyisoroofinsulation',
#  'hunterpanels46x4x8hshieldnb58plywoodfiberreinforcedfacerpolyisoinsulation',
#  'lapollaindustriesfoamlok750highyieldocsprayfoamparta520lbdrum',
#  'wrmeadows12x4x10fiberexpansionjoint',
#  'bergerbuildingproducts16oz3plainroundcopper30elbow',
#  'bergerbuildingproducts44x158paintedaluminumpoprivetcartonof1000darkbronze',
#  'insulationcorporation5x4x8eps1lbdensity',
#  'isolatekcafcofendolitemiihighdensitywetmixsprayappliedfireresistivematerial44lbbag',
#  'cetcoadhesivesb1005gallonpail',
#  'bergerbuildingproducts3x10plainrounddownpipealmond',
#  'awardmetals5kstylegutterendcapleft',
#  'bergerbuildingproducts16oz3x10roundcorrugatedcopperdownspout',
#  'hunterpanels25x4x8hshieldffoilfacedpolyisoinsulation',
#  'bergerbuildingproducts26gauge3x4outsidesquarecorrugatedgalvanized3offsets',
#  'derbigum112x4x8derbiboardisopolyisocyanurateroofinsulationboard',
#  'atasmetals6hiddenhanger',
#  'bergerbuildingproducts6x4kstylediamondguttershieldcartonof25white',
#  'qualityedge024x15x61truguardaluminumgutterprotectionpanelonlyblack',
#  'usaluminum238wideflangepopinoutlet',
#  'englert032x5aluminumguttercoilpaintedononesidesoldperlinfthighglosswhite',
#  'newhollandengineering6hiddenhangercartonof700',
#  'bergerbuildingproducts26gauge6halfroundinsidegalvalume90stripmiter',
#  'alscometals5x4guttergoaliesoldindividually',
#  'hunterpanels2x4x8hshieldhdcompositecgpolyisoinsulation',
#  'certainteedinsulation612x24x48r22unfacedbatts128sqftperbag',
#  'reefindustries20x100griffolyntype55frvaporbarrier',
#  'gracoar4242fusionairpurgegunwithroundmixchamber',
#  'spectrametalsales3x4elbowwith4offsetmusketbrown',
#  'carlislecoatingswaterproofing500hotappliedwaterproofingmembrane45lbblock',
#  'certainteedroofing212x4x8grade220psipolyiso',
#  'edcoproducts5aluminumleftendcapenamelfinishpolarwhite',
#  'owenscorning614x23x392r19rf41ecotouchpinkfiberglaskraftfacedrollinsulationwithpurefibertechnology7507sqftroll',
#  'mastic5aluminumhiddenhanger',
#  'tribuilt12x6woodfibertaperededge288linftbundle',
#  'bergerbuildingproducts4copperdownspouttube',
#  'bergerbuildingproducts26gauge6x16halfroundsinglebeadgalvanizedsteelgutter',
#  'hunterpanels1x4x4hshieldgradeii20psipolyisoinsulationwithfiberreinforcedfacers',
#  'bergerbuildingproductsmillfinishaluminumrodnutsforaluminumregalbarhanger',
#  'bergerbuildingproducts26gauge3plainroundgalvanizedsteel60elbow',
#  'thermafoam2312x1912x312x8epsflutefiller1lb',
#  'bergerbuildingproducts16oz6halfroundcopperslipjoint',
#  'bergerbuildingproductsgalvanizedsteeluniversalconductorband',
#  'johnsmanvilleq05to254x4taperedenrgy3gradeiii25psipolyisoroofinsulation',
#  'bergerbuildingproductscopperuniversalconductorband',
#  'buchnermanufacturing5screwonnoclipgutterhanger12',
#  'atlasroofingtt2to312tapered4x4polyisoroofinsulation',
#  'usply58x4x8securlockgypsumfiberroofboard',
#  'basfmasterprotecth1001silanepenetratingsealer55gallondrum',
#  'durolast05to25tapered4x4isoqpanel',
#  'hunterpanels3x4x8hshieldgradeii20psipolyisoinsulationwithfiberreinforcedfacers',
#  'hunterpanels15x4x8hshieldcgcoatedglassfacerpolyisoinsulation',
#  'bergerbuildingproducts24gauge3x10roundcorrugatedgalvanizedsteeldownspout',
#  'englert6aluminumendcaprightmusketbrown',
#  'georgiapacific14x4x4densdeckprimeroofboard',
#  'owenscorning71x23x47thermafiberultrabattmineralwoolinsulation225sqftbag',
#  'wrmeadows12x5x10fibreexpansionjoint',
#  'bergerbuildingproducts7kstylerightendcapdarkbronze',
#  'bergerbuildingproducts16oz6x10halfroundfreedomgraycopperguttersinglebead',
#  'firestonebuildingproducts054x4fibertoproofinsulation',
#  'huebertfiberboard12x4x4woodfiberroofinsulation1side',
#  'gcpappliedtechnologiespermabarriernpl10lt5gallonpail',
#  'lucasspecialtyrockb434to114x14taperedperliteboard',
#  'variformbyplygem2x3premiumdownspoutsedonared',
#  'owenscorning5x24x48thermafibersafbmineralwoolinsulation40sqftbag',
#  'certainteedinsulation312x15x105sustainabler15kraftfacedbatts875sqftperbag',
#  'siplast2x4x4isocoatedglassfacer',
#  'englert5aluminumhdhiddenhanger',
#  'soprema120mil394x328colphenebswv1sqroll',
#  'hunterpanels26x4x8hshieldgradeii20psipolyisoinsulationwithfiberreinforcedfacers',
#  'bergerbuildingproducts20oz3x10plainroundcopperdownspout',
#  'bergerbuildingproducts26gauge3roundcorrugatedgalvanizedsteel60elbow',
#  'bergerbuildingproducts125x8kstylestainlesssteelcustomcrossbarhanger',
#  'tegraseal312x2112tegratitepluswaterproofingmembrane',
#  'englert5aluminumhangerwithscrewclipnonhemback',
#  'graco14x202000psiheatedwhiphosewithxtremescuffguard',
#  'owenscorning312x15x105r15k97ecotouchpropinkfastbattfiberglaskraftfacedbattinsulationwithpurefibertechnology8750sqftbag',
#  'bergerbuildingproducts26gauge5roundcorrugatedgalvanizedsteel75elbow',
#  'genflexx12to112tapered4x4polyisoinsulation',
#  'johnsmanville91415x25unfacedfiberglassnarrowrollinsulation3125sqftroll',
#  'bergerbuildingproducts6x4kstyletitanguardaluminumflatgutterguardmillfinish',
#  'vaproshieldvaprobondsiliconesealant20ozsausage',
#  'rockwool714x1514x47comfortbattr30299sqftbag',
#  'atlasroofing112x4x4acfoamiipolyisogrfroofinsulation',
#  'owenscorning4x36x60thermafiberfirespan90foilfacedmineralwoolinsulation30sqftbag',
#  'spectrametalsalesgutterwedgewhite',
#  'mastic5leafreliefadjustablecopper',
#  'firestonebuildingproducts44x8iso95glgradeiii25psipolyisoroofinsulation',
#  'hunterpanels27x4x8xcinbverticalnailablepolyisoinsulationwithcgfand34plywood',
#  'huebertfiberboard1x4x8woodfibercoatedhighdensityroofinsulation',
#  'bergerbuildingproducts125x8kstylestainlesssteelcustomcrossbarhanger',
#  'dow4x100weathermatestraightflashing',
#  'metaltech238roundaluminumoutlet',
#  'edcoproducts5aluminumleftendcappvcfinishclassicred',
#  'lambritchie3roundcorrugatedaelbowwhite',
#  'gcpappliedtechnologiesbitutheneprimerwp30005gallonpail',
#  'rmax26x4x8ultramaxabovethedeckpolyisoinsulation',
#  'basfmasterprotectc350mediumtintbasecoating5gallonpail',
#  'bergerbuildingproducts16oz3plainroundcopper30elbow',
#  'qualityedge019diamondpipebandwicker809',
#  'siplast312x4x4isopanel',
#  'henrycompanyairbloc17mrairbarriermembrane55gallondrumgraphite',
#  'mastic5leafreliefoutsidecorner',
#  'continentalmaterials12x4x8highdensityfiberboard',
#  'rockwool4x2x4afbbattinsulation64sqftbag',
#  'euclidchemicaleucoqwikjointuvruvresistantpolyureafloorjointfillerpartb5gallonpailstandardgrey',
#  'bergerbuildingproducts26gauge6x20halfroundgalvanizedsteelguttersinglebead',
#  'gaf144x8densdeckroofboard',
#  'polyglasspolypuf25spraypolyurethanefoamroofinginsulationgradesslowpartb50gallondrum',
#  'firestonebuildingproducts584x8densdeckprimeroofboard',
#  'bergerbuildingproducts032x5x21kstylepaintedaluminumgutterhembackroyalbrown',
#  'mastic5insideboxmiterjeffersontan',
#  'hunterpanelsy15to25tapered8x8hingedtargetdrainsumpwith14slope',
#  'georgiapacific12x4x1445toughrocklightstronggypsumboard',
#  'bergerbuildingproducts16oz3x4squarecorrugatedcopper5offsets',
#  'bergerbuildingproducts20oz5x10halfroundcopperguttersinglebead',
#  'lyftymbuildingproducts2x3x10downspoutcharcoalgrey',
#  'bergerbuildingproducts16oz6x20kstylecoppergutterstraightback',
#  'bergerbuildingproducts16oz5x23halfroundsinglebeadcoppergutter',
#  'englert5stainlesssteelstraightbackaluminumbarhanger',
#  'mastic6x15guttercoilcameo',
#  'gracofusionairpurge80meshgunfilterpackof2',
#  'bergerbuildingproducts019x3plainroundmillfinishaluminum75elbow',
#  'usaluminum5x4shurflostepdowngutterguardmillfinish',
#  'bergerbuildingproducts18oz6permanentcoppergutterconnectorwithrubberseals',
#  'performanceroofsystems212to312taperedisozpanelca',
#  'owenscorning312x16x96r11m41qecotouchpinkfiberglasunfacedbattinsulationwithpurefibertechnology17067sqftbag',
#  'bergerbuildingproducts16oz6x10halfroundcopperguttersinglebead',
#  'bergerbuildingproducts5euracraftcopperrightendcap',
#  'johnsmanvillecorbondiiiclosedcellspraypolyurethanefoamsidea55gallondrum',
#  'gracofusionairpurgeflat01mixchamberkit',
#  'certainteedinsulation312x16x96r11acousticalthermalbatts17067sqftperbag',
#  'qualityedge5outsidestripmitredeserttan',
#  'rmax15x4x8tsx8510polyisoinsulation',
#  'cantproducts1x24taperededge32linftbundle',
#  'owenscorning3x48x72thermafiberfirespan40foilfacedmineralwoolinsulation24sqftbag',
#  'bergerbuildingproducts032x7x25kstylepaintedaluminumgutterhembackroyalbrown',
#  'carlislesyntec124x50rtecheps125lbdensityfanfoldrecoverboard',
#  'gcpappliedtechnologiespermabarriervpo5gallonpail',
#  'johnsmanville122x4fescoperlitebasedcoverboard192sqftbundle',
#  'bergerbuildingproducts20oz8x10kstylecoppergutterstraightback',
#  'bergerbuildingproducts5halfroundinsidemillfinishaluminum90miter',
#  'mastic27milx5x1178guttercoilsoldbythelbblack',
#  'cetco4x25volclayultrasealbt',
#  'certainteedroofing2x4x8grade220psipolyiso',
#  'usaluminum5speedscrewhangerwithoutclip',
#  'bergerbuildingproducts5copperferrule',
#  'kingspaninsulation4x100greenguardbutylflashingtape',
#  'tamko12x61tw60selfadheringsheetwaterproofingmembranewintergrade',
#  'gaf054x8energyguardhdplusgradeii110psipolyisoroofinsulation',
#  'certainteedinsulation312x24x96r13unfacedbatts208sqftperbag',
#  'bergerbuildingproducts18oz6x4euracraftcopperpluginoutlet',
#  'rockwool112x2x4afb128sqftbag',
#  'soprema40mil36x75colpheneicfselfadhesivewaterproofingmembrane2sqroll',
#  'bergerbuildingproductshalfroundbrassspringclipforgemcircle10combohanger',
#  'sopremaalsanrsgrade1quartzaggregate50lbbag',
#  'edcoproducts5aluminuminsideboxmitreentexfinishhartfordgreen',
#  'wrmeadows18x4x8protectioncoursepc2standarddutywaterproofingprotectionboard',
#  'qualityaluminumproducts4fasciacapimperialbrown',
#  'bergerbuildingproducts5halfroundpaintedaluminumgemcirclewithspringclipnutboltroyalbrown',
#  'spectrametalsales12x8zipscrewcream',
#  'cantproducts112x24perlitetaperededge24linftbundlelightgrey',
#  'englert027x1134guttercoilsoldperlinft',
#  'sprayfoamsystems0202csmixingchamber',
#  'rmax15x4x8tsx8510polyisoinsulation',
#  'hunterpanels0to1taperedhshield4x4polyisoinsulation',
#  'm5steel2x3x20bonderizedsteelrectangulardownspout',
#  'bergerbuildingproductssnapinpvcguttercoverwithmeshfits56kstylegutterbrown',
#  'fortifiber40x72superjumbotex60minutegradedweatherresistivebarrier240sqft',
#  'blueridgefiberboard112x4cantstrips120bundle',
#  'bergerbuildingproducts16oz6x17halfroundcopperguttersinglebead',
#  'bergerbuildingproducts26gauge3x4squarecorrugatedastylegalvanizedsteel75elbow',
#  'bergerbuildingproducts16oz6x32halfroundcopperguttersinglebead',
#  'insulfoamc2taperedeps4x8roofinsulation125pcfdensity',
#  'owenscorning112x16x48thermafiberrainbarrier45continuousmineralwoolinsulation',
#  'qualityedge019tstrap',
#  'newtechmachinery6machiiguttermachine',
#  'certainteedinsulation612x16x48sustainabler22unfacedbatts8533sqftperbag',
#  'bergerbuildingproducts16oz3x4squarecorrugatedastylecopper75elbow',
#  'wrmeadows3812x60melrollowtempwaterproofingmembrane',
#  'certainteedinsulation614x2314x48sustainabler19unfacedbatts138sqftperbag',
#  'cetco36x67rap400sa',
#  'owenscorning312x15x93r11wb8aquietzoneacoustickraftfacedbattinsulationwithpurefibertechnology155sqftbag',
#  'rmax15x4x8tsx8510polyisoinsulation',
#  'midstatesasphalt1x12x48perlitetaperededgestrip',
#  'hunterpanels3x4x8hshieldffoilfacedpolyisoinsulation',
#  'thermafoam2x1514x8epsflutefiller',
#  'bergerbuildingproducts6x10kstyletitanguardaluminumstepupgutterguardmillfinish',
#  'hunterpanelsb15to2precuthippolyisoinsulation',
#  'atasmetals6gutterrightendcap',
#  'hunterpanels05x4x8hshieldgradeii20psipolyisoinsulationwithfiberreinforcedfacers',
#  'houstonfoamplastics14x4x50fanfoldepsinsulation10lbdensity2sqbundle',
#  'bergerbuildingproducts16oz3roundcorrugatedcopper75elbow',
#  'artssheetmetal3roundx5longroofoutlet',
#  'carlislecoatingswaterproofinglm800xlliquidmasticwintergrade29oztube',
#  'firestonebuildingproducts24x8resistagradeiii25psipolyisoinsulation',
#  'carlislecoatingswaterproofingmiraclaysealant5gallonpail',
#  'bergerbuildingproducts24gauge3x4x10squarecorrugatedgalvanizedsteeldownspout',
#  'huebertfiberboard12x4x4woodfibercoatedhighdensityroofinsulation',
#  'carlislecoatingswaterproofing12endoutconnectorformiradrainhcblack',
#  'owenscorning312x16x96r15f95ecotouchpinkfiberglaskraftfacedbattinsulationwithpurefibertechnologybagof7467sqft',
#  'lambritchie5leftendcapwhite',
#  'bergerbuildingproducts26gauge8x10halfroundgalvanizedsteelguttersinglebead',
#  'universalpolymerscorporation500maxfastopencellpolyurethanefoaminsulationparta500lbdrum',
#  'henrycompany4x75blueskinsaselfadheredairvaporbarriermembraneblue',
#  'frostking6x20plasticmeshgutterguardblack',
#  'masterbuilderssolutionsmastersealm270np2componentmembrane',
#  'basfmastersealnp150hybridsealant20ozpropakwhite',
#  'bergerbuildingproducts26gauge3plainroundgalvanizedsteel3offsets',
#  'carlislecoatingswaterproofing6x100ccw705ltlowtempairvaporbarrierstrips',
#  'mastic5x8leaflogic',
#  'convenienceproducts750foamkitfr',
#  'bergerbuildingproducts26gauge3x10plainroundpaintgripsteeldownspout',
#  'bergerbuildingproducts3kstyleovalmillfinishaluminumoutletwithlockindesign',
#  'mastic27milx5x1134guttercoilsoldbythelbeverest',
#  'fomoproductshandistickgeneralusegunfoam20ozcan',
#  'atlasroofing2x4x4acfoamiiigradeiii25psipolyisocgfroofinsulation',
#  'georgiapacific12x4x8toughrockgypsumboard',
#  'ecocell512x16x8cellulosebattinsulation',
#  'bergerbuildingproducts16oz5x30halfroundcopperguttersinglebead',
#  'certainteedroofingx12to112tapered4x4grade220psipolyiso',
#  'artssheetmetal3roundx5longroofoutlet',
#  'bergerbuildingproducts2x3squaregalvanizedsteelsicklehookforwood',
#  'bergerbuildingproducts26gauge6x10kstylegalvanizedsteelgutterstraightback',
#  'owenscorning312x16x96r11m41qecotouchpinkfiberglasunfacedbattinsulationwithpurefibertechnology17067sqftbag',
#  'spectrametalsales6gutterguardaluminumdropincover',
#  'lyftymbuildingproducts2x3styleb75elbowdarkbronze',
#  'rmax3x4x8thermasheathfoilfacedpolyisoinsulation',
#  'remay9x75typaralltemperatureflashing',
#  'johnsmanvilleh2to34x4taperednominalgradeiii25psipolyisoinsulation',
#  'bergerbuildingproducts16oz5x10plainroundcopperdownspout',
#  'fiberlitetechnologiesincidepestcontrolcelluloseinsulation',
#  'hunterpanels39x4x8hshieldgradeiii25psipolyisoinsulationwithfiberreinforcedfacers',
#  'gracorecirculationtube',
#  'gcpappliedtechnologies2x50preprufedetailtape',
#  'owenscorning312x23x93r15u88ecotouchpinkfiberglasunfacedbattinsulationwithpurefibertechnology10398sqftbag',
#  'henrycompanyairbloc32mrairwatervaporbarriermembrane5gallonpailbeige',
#  'spectrametalsales10rounddownspoutmusketbrown',
#  'hunterpanels25x4x4hshieldgradeiii25psipolyisoinsulationwithfiberreinforcedfacers',
#  'firestonebuildingproducts124x8securockglassmatroofboard',
#  'derbigum215x4x4derbiboardisopolyisocyanurateroofinsulationboard',
#  'tegraseal12x1tegrastopwaterstop',
#  'covertechfabricating6x125doublebubblereflectivefoilinsulationwhite',
#  'insulationcorporation34x4x8eps15lbdensity',
#  'm5steel26gauge2x3x10bonderizedsteelrectangulardownspout',
#  'certainteedinsulation512x1514x105sustainabler20unfacedbatts8750sqftperbag',
#  'wrmeadows12x5x10fibreexpansionjoint',
#  'gracorac5switchtipkit',
#  'hunterpanels25x4x8compositewithfb',
#  'graco53cleanoutdrillbitrepairkit',
#  'cetco54x50coreflashuvroll',
#  'mbcimetalbuildingcomponentsgutterstraps',
#  'carlislecoatingswaterproofing18x100uncuredneopreneflashingmembraneblack',
#  'bergerbuildingproducts16oz2x3squarecorrugatedastylecopper75elbow',
#  'basfmastersealsl2slopegradepretinted15galloncanlimestone',
#  'hunterpanels2x4x8hshieldhdcompositecgpolyisoinsulation',
#  'bergerbuildingproducts26gauge6x26halfroundgalvanizedsteelguttersinglebead',
#  'bergerbuildingproducts032x6x20kstylemillfinishaluminumgutter',
#  'hunterpanels25x4x8hshieldcgcoatedglassfacergradeii20psipolyisoinsulation',
#  'mastic3x4downspoutwith6offsetwhite',
#  'bergerbuildingproducts1millfinishaluminumshankplateforfascia',
#  'bergerbuildingproducts18oz5euracraftcopperquarterballendcap',
#  'metaltechgutterguardezstepdown6small',
#  'bergerbuildingproducts16oz5x20halfroundfreedomgraycopperguttersinglebead',
#  'variformbyplygem4smoothrounddownspoutdarkbronze',
#  'rmax33x4x8multimaxfaabovethedeckpolyisoinsulation',
#  'bergerbuildingproducts5x3halfroundhingedmillfinishaluminumgutterguardcartonof50',
#  'bergerbuildingproducts2x3stylebsquareplain75elbowroyalbrown',
#  'spectrametalsales3x4x10stainlesssteeldownspoutlinen',
#  'georgiapacific58x4x8denselementbarrier',
#  'qualityaluminumproducts5outsidemitresandstonebeige',
#  'bergerbuildingproducts16oz2x3squarecorrugatedbstylecopper45elbow',
#  'gracofusionproconnectround02mixchamberwith0052orificesize',
#  'mastic5envoycombinationhanger',
#  'graco38x502000psiheatedhosewithxtremescuffguard',
#  'styroindustriestaperededgewf012x12',
#  'qualityedge019x5inside45baystripmitrewhite515',
#  'remay412x100typarhousewrap',
#  'osigs121gutterseamsealant10flozcartridgeclear',
#  'bergerbuildingproducts640kpaintedaluminumfasciahangerwithsnapstraphighglosswhite',
#  'usaluminum6x10shurfloflatgutterguard',
#  'amerimax3x3c6galvanizedroofedgewhite',
#  'usaluminum6gutterwedgewhite',
#  'atlasroofing312x4x4acfoamiiigradeii20psipolyisocgfroofinsulation',
#  'spectrametalsales5outsidebaystripmiterwhite',
#  'atasmetals7hiddenhanger',
#  'bergerbuildingproducts019x3x10plainroundmillfinishaluminumdownspout',
#  'bergerbuildingproducts16oz5x18kstylecoppergutterstraightback',
#  'cathedralstoneproducts24jahnfinishingmiterrod',
#  'fomoproductshandifoamwindowdoorstrawfoam12ozcan',
#  'bergerbuildingproducts18oz4euracraftcopperswanneckoffset',
#  'hunterpanels4x4x4hshieldcgcoatedglassfacerpolyisoinsulation',
#  'hunterpanelsd25to3taperedhshieldgradeiii25psipolyisoinsulationwithfiberreinforcedfacers',
#  'usaluminum6doubleribhangerwithclipboxof600',
#  'kingspaninsulation4x75greenguardbutylflashingtape',
#  'convenienceproductsnozzlekitwithfansprayfoamnozzleyellow',
#  'rheinzink5crchalfroundrightendcap',
#  'atlasroofing235x4x4cgfcoatedglassfacerpolyisoroofinsulation',
#  'bergerbuildingproducts16oz4plainroundcopper45elbow',
#  'atlasroofing23x4x8acfoamiigradeii20psipolyisoroofinsulation',
#  'bergerbuildingproducts019x4plainroundpaintedaluminum5offsetsroyalbrown',
#  'hunterpanels15x4x8hshieldcgcoatedglassfacerpolyisoinsulation',
#  'bergerbuildingproductsfreedomgraycopperrackkey',
#  'owenscorning512x15x105r21k27ecotouchpinkfiberglasunfacedbattinsulationwithpurefibertechnology8750sqftbag',
#  'touchnseal2componentkit200',
#  'englert5aluminumoutsidemiterloglosswhite',
#  'bergerbuildingproducts16oz5plainroundcopper90elbow',
#  'gafolybond500spotshotinsulationadhesivedualtubesetindividualset',
#  'awardmetals4x6gutterleaderhead',
#  'owenscorning3x7x36thermafibertopstopheadofwallmineralwoolinsulation',
#  'midstatesasphalt12x6x48woodfibertaperededgestrip',
#  'insulationcorporation112x4x8eps15lbdensity',
#  'henrycompany91001penetratingasphaltprimer5gallonpailblack',
#  'usaluminum5heavydutyhiddenhangerdrumof1800',
#  'durolast235x4x8isogradeii20psi',
#  'edcoproductsaluminumgutterapronentexfinishroyalbrown',
#  'sika4x4x8sarnathermpolyisoinsulation',
#  'insulationcorporationaviliteepsflutefiller',
#  'fomoproductshandifoamwindowdoorgunfoam24ozcan',
#  'owenscorning512x14x50foamsealrsillplategasketsingleroll',
#  'artssheetmetalraindivertershake',
#  'tremcoacousticalcurtainwallsealant',
#  'remay6x75typarflexibleflashing',
#  'edcoproducts3x4aluminumdownspoutenamelfinishpolarwhite',
#  'rmax25x4x8multimaxfaabovethedeckpolyisoinsulation',
#  'bergerbuildingproducts16oz6kstyleoutsidecopper90boxmiter',
#  'gcpappliedtechnologies18x75permabarrierwallflashing',
#  'rheinzink318crcdownspout',
#  'baycitiesmetalproducts26gauge2x6x10galvanizedlmetal',
#  'blueridgefiberboard12x4x8structodekhdfiberboardwith1sidecoating',
#  'bergerbuildingproducts032x6x28halfroundsinglebeadpaintedaluminumgutterroyalbrown',
#  'wrmeadows6x50pmpctape',
#  'carlislecoatingswaterproofing12miradrainhcsideoutconnector',
#  'unitedasphaltnewjersey5fiberboardcantstrip96bundle',
#  'bergerbuildingproducts16oz6x20halfroundcoppergutterreversebead',
#  'hunterpanels2x4x8xciconcastgradeiii25psireinforcedfoilfacerpolyisoinsulation',
#  'mastictouchuppaintaerosol12ozcanmistyshadow',
#  'bergerbuildingproducts16oz5x3halfroundcopperendpiece',
#  'dupont4x75flashingtape',
#  'basfmasterprotecthb400waterproofcoatingcoarsemediumtintbase5gallonpail',
#  'bergerbuildingproducts2x3squaregalvanizedsteelsicklehookforwood',
#  'basfmasterprotectp150acrylicprimersmoothtexture5gallonpail',
#  'gracoe20exp1reactormotorcontrolboardkit',
#  'spectrametalsales027x15guttercoilcolonialgrey',
#  'gcpappliedtechnologies18x667bituthene3000membrane',
#  'gracofusionairpurgegreaselube4oztube',
#  'gacowesterngacoonepassf1850closedcellsprayfoaminsulationpartbwintergrade55gallondrum',
#  'owenscorning48thermafiberfixtureshieldlightprotectionkitcartonof6',
#  'rockwool5x16x48cavityrock',
#  'genflex2x4x8polyisoinsulation25psimin',
#  'hunterpanels1x4x10xcifoilfacerpolyisoinsulation',
#  'gracoadmmodulekitforreactor2e30andesp2proportioningsystem',
#  'genflex3x4x8polyisoinsulation',
#  'bergerbuildingproducts3rdgalvanizedsteelbricksicklehookroyalbrown',
#  'certainteedinsulation312x1514x93sustainabler13unfacedbatts12594sqftperbag',
#  'polyglasspolypuf30spraypolyurethanefoamroofinginsulationgradesslowpartb50gallondrum',
#  'bergerbuildingproducts3x4to4squaretoroundtileadapterblack',
#  'bergerbuildingproducts16oz3x4x10squarecorrugatedlightcoatedcopperdownspout',
#  'owenscorning30x23x47firesoundguard601sqftbag',
#  'bergerbuildingproducts024x4plainroundpaintedaluminum75elbowterrabronze',
#  'georgiapacific9x150prolinxselbuildingwrap',
#  'atlasroofing2x4x4acfoamiiigradeiii25psipolyisocgfroofinsulation',
#  'mastic5leafreliefcopperhalfround',
#  'rockwool5x16x4afbbattinsulation4267sqftbag',
#  'owenscorning112x412x36thermafibertopstopheadofwallmineralwoolinsulation',
#  'klauermanufacturingcompany2x3classicaluminumastyleelbowsnowwhite',
#  'cetco36x667envirosheetselfadheringwaterproofingmembrane2sqroll',
#  'johnsmanvillehidenblowingwool32sqftbag',
#  'johnsmanvillespiderplusblowinwool30lbbag',
#  'mastic32milx6seamlessguttersoldperlinftevergreen',
#  'bergerbuildingproducts26gauge4roundcorrugatedgalvanizedsteel75elbow',
#  'rockwool4x16x4afbbattinsulation64sqftbag',
#  'bergerbuildingproducts26gauge5kstyleleftgalvanizedsteelendcap',
#  'hunterpanelsa1to15taperedprecutvalleypolyisoinsulation',
#  'rockwool3x2x4curtainrock80uf32sqftbag',
#  'bergerbuildingproducts3x4astylepaintedaluminum30elbowalmond',
#  'bergerbuildingproducts5kstylepremiumcopperfasciahangerwithcrossbar',
#  'bergerbuildingproducts5aluminumh7hiddenhangerwithstainlesssteelstrapmillfinish',
#  'usaluminum5speedscrewhangerwithclip',
#  'johnsmanvilleb8075to12x4taperedfescoperlitebasedcoverboard80sqftbundle',
#  'cetco40x379swelltite',
#  'gcpappliedtechnologiessilcor900haliquidwaterproofingpartaonly02gallonbottle',
#  'cetcocoretexxpapcdetailsheet1sqroll',
#  'bergerbuildingproducts032x5x16halfroundpaintedaluminumguttersinglebeadroyalbrown',
#  'bergerbuildingproducts16oz3plainroundcopper5offsets',
#  'rockwoolcomfortbattr2324oc',
#  'bergerbuildingproducts26gauge6kstylerightpaintgripsteelendcap',
#  'certainteedinsulation614x1514x93sustainabler19unfacedbatts8719sqftperbag',
#  'bergerbuildingproducts027x5x24halfroundsinglebeadpaintedaluminumgutterroyalbrown',
#  'sikaq12to212tapered4x4sarnathermpolyisoinsulation',
#  'basfmasterprotecth185waterrepellentsealer5gallonpail',
#  'rockwooly112to212monoboardtaperedpanel',
#  'certainteedinsulationcertasprayasidemdifoam',
#  'dowdowsilallguardsiliconeelastomericcoatingmidtintbase5gallonpail',
#  'atlasroofing21x4x8acfoamnailbasenailableroofinsulationwith58cdx',
#  'georgiapacific58x4x10fireresistantgypsum',
#  'mazenails8doublehotdipgalvanizedplainshankgutterspikes50lbcarton',
#  'rockwool2x2x4cavityrock',
#  'hunterpanels16x4x8hshieldgradeii20psipolyisoinsulationwithfiberreinforcedfacers',
#  'awardmetals514curvedfasciaendcap',
#  'unitedasphaltnewjersey112x18perlitetaperededge48bundle',
#  'bergerbuildingproducts3x4zincsquaresidefastenhook',
#  'bergerbuildingproducts5aluminumh7hiddenhangerwithstainlesssteelstrapmillfinish',
#  'kingspaninsulation4x75greenguardbutylflashingtape',
#  'spectrametalsales6outsideboxmitermusketbrown',
#  'bergerbuildingproducts16oz6x17halfroundcopperguttersinglebead',
#  'dupont234x15tyvekflexwrapez',
#  'carlislesyntec14x8foilpolyisoinsulation',
#  'bergerbuildingproducts30galvanizedsteelshankforadjustablepitchraftersfascia',
#  'johnsmanville3121514x105tablesskraftfacedfiberglassbattinsulation12231sqftbag',
#  'usaluminum5hangerwithclip',
#  'johnsmanville61223x93comfortthermpolywrappedfiberglassbattinsulation13368sqftbag',
#  'insulfoam2x4x8rtechivepsroofinsulation',
#  'gracopackingoringt2',
#  'bergerbuildingproducts16oz4x10plainroundcopperdownspout',
#  'bergerbuildingproducts26gauge6x16halfroundsinglebeadgalvanizedsteelgutter',
#  'westcoatspecialtycoatingsystemsec95gglosspolyurethanetopcoat1gallonkitsafetyyellow',
#  'covertechfabricating6x125doublebubblereflectivefoilinsulationwhite',
#  'rockwool35x2x4afbbattinsulation64sqftbag',
#  'bergerbuildingproducts5kstylepaintedaluminumcrossbarforpremiumfasciahangerroyalbrown',
#  'johnsmanvillecorbondiiiclosedcellspraypolyurethanefoamsidea55gallondrum',
#  'osigs121gutterseamsealant5flozsqueezetubewhite',
#  'insulationcorporation112x4x8aviliteeps1lbdensity',
#  'bergerbuildingproducts7kstylepaintedaluminumleftendcaproyalbrown',
#  'unitedasphaltnewjersey5perlitecantstrip96bundle',
#  'bergerbuildingproducts26gauge6x10kstylegalvanizedsteelgutterstraightback',
#  'gracofusionairpurgelargefluidhousingoringpackof6',
#  'gracofusioncsgun',
#  'awardmetals514x25bonderizedfasciadecoface',
#  'insulfoamc1taperedeps4x8roofinsulation125pcfdensity',
#  'hunterpanels25x4x8compositewithfb',
#  'gafolybond500insulationadhesivepart2wintergrade5gallonbaginbox',
#  'performanceroofsystemstaperedxpanelgradeiiiinsulation',
#  'lowereflectiveinsulation14x4x125housewrap500sqroll',
#  'convenienceproductssharpshooter39foamgun',
#  'performanceroofsystems12to212tapered4x4isoqpanel',
#  'bergerbuildingproducts26gauge4roundcorrugatedgalvanizedsteel75elbow',
#  'bergerbuildingproducts019x3x4squarecorrugatedbstylepaintedaluminum75elbowroyalbrown',
#  'fortifiber40x72superjumbotex60minutegradedweatherresistivebarrier240sqft',
#  'carlislecoatingswaterproofingmirastopflexiblechemicalgroutcatlayst32ozcan',
#  'awardmetals134x234galvanizedsquarepipestrap',
#  'bergerbuildingproducts024x3x4x10squarecorrugatedpaintedaluminumdownspoutheritagecream',
#  'bergerbuildingproducts16oz3kstyleovalcopperoutletwithlockindesign',
#  'bergerbuildingproductssnapinpvcguttercoverwithoutmeshfits56kstylegutterswhite',
#  'carlislecoatingswaterproofing4x50miradrain9800drainagecomposite',
#  'gracot2transferpump21ratio',
#  'continentalmaterials1x4x4highdensityfiberboard',
#  'dowfrothpak650foaminsulationkit',
#  'qualityaluminumproducts134x10aluminumgutterapronhickory',
#  'bergerbuildingproducts6kstyleoutsidepaintedaluminum90stripmiterblack',
#  'bergerbuildingproducts3kstyleovalmillfinishaluminumoutletwithlockindesign',
#  'alldeckenviromentalcoatingsystemssprayaggregate2gallonpail',
#  'fomoproductshandifoame84class1aii605',
#  'performanceroofsystems1to112tapered4x4isoapanel',
#  'bergerbuildingproducts019x3roundcorrugatedpaintedaluminum90elbowblack',
#  'rockwool3x2x4comfortboard11024sqftbag',
#  'bergerbuildingproducts027x6x34halfroundsinglebeadpaintedaluminumgutterblack',
#  'bergerbuildingproducts032x11785kstandardpaintedaluminumguttercoilwhite',
#  'huttigbuildingproducts9x100rexwraphousewrap',
#  'lambritchie3roundleafstrainer',
#  'bergerbuildingproducts6millfinishaluminumdrive',
#  'hunterpanels3x4x8xci286gradeiii25psireinforcedfoilfacerpolyisoinsulation',
#  'bergerbuildingproducts032x6x24halfroundsinglebeadpaintedaluminumgutterroyalbrown',
#  'ecocell212x4x8celluloseinsulation',
#  'lucasspecialtyrock1x18perlitetaperededgestrip80linftbundle',
#  'bergerbuildingproducts16oz3halfroundcopperbstyleoutlet',
#  'qualityedge019x5outside45baystripmitrewhite515',
#  'bergerbuildingproducts4roundgalvanizedsteelwirestrainer',
#  'dowdowsilallguardsiliconeelastomericcoatingpasteltintbase5gallonpail',
#  'bergerbuildingproducts6x3halfroundhingedmillfinishaluminumgutterguard',
#  'georgiapacific58x4x9densshieldtilebackerboard',
#  'durolast2x4x4iso',
#  'basfmasterprotectel750waterproofcoatingsmoothtexture5gallonpailmediumtintbase',
#  'hunterpanelsaa05to1precuthippolyisoinsulation',
#  'hunterpanels34x4x8xcifoilfacerpolyisoinsulation',
#  'rmaxy15to25tapered4x4gradeii20psipolyisoinsulationpanel',
#  'awardmetals28gauge134x23490styleaelbow',
#  'bergerbuildingproducts16oz6x30halfroundfreedomgraycopperguttersinglebead',
#  'bergerbuildingproducts5kstylepaintedaluminumoutsidemiterdarkbronze',
#  'sopremag1to24x4taperedgradeii20psipolyisoinsulation',
#  'carlislecoatingswaterproofing12hcspliceconnector',
#  'gracosinglehosefluidtemperaturesensorkitwithrtd',
#  'bergerbuildingproducts032x6x33halfroundpaintedaluminumguttersinglebeadroyalbrown',
#  'hunterpanels15x4x4hshieldcgcoatedglassfacerpolyisoinsulation',
#  'insulfoamc10taperedeps4x8roofinsulation125pcfdensity',
#  'mastic5leafreliefcombohanger',
#  'huebertfiberboard12x4x4woodfiberroofinsulation',
#  'gracotransducerkit',
#  'bergerbuildingproducts18oz71425x4euracraftcopperpluginoutlet',
#  'sikaa1to112tapered4x4sarnathermpolyisoinsulation',
#  'mastic32milx5x13guttercoilsoldbythelbalmond',
#  'insulationcorporation112x4x8eps1lbdensity',
#  'hunterpanels25x4x4hshieldgradeii20psipolyisoinsulationwithfiberreinforcedfacers',
#  'baycitiesmetalproducts4x6x12galvanizedtilepan',
#  'bergerbuildingproducts16oz3x4squarecorrugatedcopper2offsets',
#  'bergerbuildingproducts6x3kstylehingedcoppergutterguardcartonof25',
#  'hunterpanels2x4x8hshieldnbpolyisoinsulationwith716osbandfiberreinforcedfacer',
#  'hunterpanels16x4x8hshieldnbpolyisoinsulationwith58osbandfiberreinforcedfacer',
#  'bergerbuildingproducts26gauge5x26halfroundgalvanizedsteelguttersinglebead',
#  'bergerbuildingproducts16oz3x4squarecorrugatedcopper3offsets',
#  'bergerbuildingproducts5euracraftcopperfasciahangerwithspringtab',
#  'insulfoamc2taperedeps4x8roofinsulation125pcfdensity',
#  'cetcocetseal101oztube',
#  'basfmasterseal610coldappliedwaterbasedcoating5gallonpail',
#  'performanceroofsystems212x312tapered4x4isozpanel',
#  'bergerbuildingproducts027x6x20halfroundpaintedaluminumgutterreversebeaddarkbronze',
#  'durolast15to25tapered4x4isoypanel',
#  'variformbyplygem3x4stylepremium30aelbowterratone',
#  'englert032x1134guttercoilsoldperlinft',
#  'owenscorning2x16x48thermafiberrainbarrierhdmineralwoolinsulation',
#  'bergerbuildingproducts3x4copperedsquaresidefastenhook',
#  'rheinzink318crcdownspoutbracket',
#  'wrmeadowspourthanensnonsagjointsealant101oztubetan',
#  'henrycompanyn031212x360filterfabric3oz',
#  'bergerbuildingproducts316x8galvanizedsteelkstylegutterspike',
#  'bergerbuildingproducts16oz4x5squarecorrugatedbstylecopper90elbow',
#  'bergerbuildingproducts6galvanizedsteeldrive',
#  'insulfoam15x4x8typeiiblowgradeepsinsulation',
#  'unitedasphaltnewjersey5fiberboardcantstrip96bundle',
#  'qualityaluminumproducts6leftendcaproyalbrown',
#  'wrmeadows4x6koolrodbackerroddarkgrey',
#  'qualityedge019x5leftendcapeldridgegrey',
#  'mastic3x4downspoutsilvergrey',
#  'hunterpanelsz25to35taperedhshieldgradeiii25psipolyisoinsulationwithfiberreinforcedfacers',
#  'owenscorning2x16x48thermafiberrainbarrier45continuousmineralwoolinsulation',
#  'fibertiteseaman3x4x8iso',
#  'cetco12dualcellweldedendcapforexpansionjointwith2centergland',
#  'allstarfoammarketingc21to2taperedfoameps4x4insulationpanel1density',
#  'carlislecoatingswaterproofing12x300liquifiber',
#  'performanceroofsystems2to3tapered4x4isohpanel',
#  'bergerbuildingproducts5x3kstylepaintedaluminumendpieceroyalbrown',
#  'bergerbuildingproducts540kcopperfasciahangerwithsnapstrap',
#  'raytec024x3x4aluminumrectangularoutletmill',
#  'bergerbuildingproducts26gaugex4plainroundgalvalume75elbow',
#  'rockwool4x24x48safe32sqftbag',
#  'hunterpanels36x4x8hshieldnbpolyisoinsulationwith58osbandfiberreinforcedfacer',
#  'gracoproblerp2standardrepairkit',
#  'midstatesasphalt112x5x48perlitecantstrip',
#  'carlislecoatingswaterproofingmirastopflexiblechemicalgroutcatlayst32ozcan',
#  'hunterpanels2x4x8xci286gradeiii25psireinforcedfoilfacerpolyisoinsulation',
#  'rockwool112x2x4comfortboard80bundleof6',
#  'bergerbuildingproducts16oz4x10roundcorrugatedcopperdownspout',
#  'qualityedge032x1178aluminumguttercoilsoldperlbeldridgegrey',
#  'bergerbuildingproductsflexaspoutgreen',
#  'owenscorning5x24x48thermafibersafbmineralwoolinsulation40sqftbag',
#  'mastic6leafreliefzip',
#  'bergerbuildingproducts019x3x4x10squarecorrugatedpaintedaluminumdownspoutdarkbronze',
#  'bergerbuildingproducts316x7copperkstylegutterspike',
#  'derbigum3x4x4derbiboardisopolyisocyanurateroofinsulationboard',
#  'englert5aluminuminsidestripmitereggshell',
#  'fibertiteseaman3x4x4iso',
#  'dow9x150weathermateplushousewrapblue',
#  'gracofusionairpurgequickchangefronthalfsprayheadkit',
#  'alscometals2x3aluminumledgejumpermusketbrown',
#  'insulfoam34x4x8rtechtypeibelowgradeeps13psiinsulation',
#  'hunterpanelsss05to2taperedhshield4x4gradeii20psifiberreinforcedfacerpolyisoinsulation',
#  'usaluminum6aluminumhiddenhangerwithscrewmill',
#  'continentalmaterials112x24taperededgefiberboard40linftbundle',
#  'cantproducts112x18taperededge32linftbundle',
#  'bergerbuildingproducts10x6halfroundcoppercombocircleshankwithspringclip',
#  'metaltech5heavydutyhanger',
#  'usaluminum5micromeshsupremegutterguardfor6gutters',
#  'tremcovulkem350rollergradebasecoat5gallonpailgrey',
#  'awardmetals13x10aluminumraindiverter',
#  'sika2x4x4sarnathermpolyisoinsulationlttr150',
#  'certainteedinsulation614x1514x105sustainabler19unfacedbatts9844sqftperbag',
#  'johnsmanvillecorbondmcsclosedcellspraypolyurethanefoamsidea55gallondrum',
#  'georgiapacific58x4x8denselementbarrier',
#  'henrycompany9x75blueskinsaselfadheredairvaporbarriermembraneblue',
#  'owenscorning312x15x93r11w03qecotouchpinkfiberglasunfacedbattinsulationwithpurefibertechnology155sqftbag',
#  'gafy15to254x4energyguardtaperedgradeiii25psipolyisoroofinsulation',
#  'insulationcorporationaviliteepsflutefiller',
#  'owenscorning512x16x93q24quietzoneacousticunfacedbattinsulationwithpurefibertechnology10333sqftbag',
#  'basfmasterprotectc350mediumtintbasecoating5gallonpail',
#  'cetco2hydrobartubescartonof16',
#  'performanceroofsystemstaperedxpanelgradeiiiinsulation',
#  'rockwoolcomfortbattr3016oc',
#  'edcoproducts2x3aluminumastyleelbowenamelfinishpolarwhite',
#  'edcoproductsaluminumgutterapronenamelfinishpolarwhite',
#  'sprayfoamsystems2712procutterclosedcellsprayfoaminsulationcuttingremovaltool',
#  'atlasroofing27x4x8polyisoroofinsulation',
#  'graco16n599highpressuresideblockforglascraftp2guns',
#  'hunterpanels37x4x8hshieldgradeii20psipolyisoinsulationwithfiberreinforcedfacers',
#  'bergerbuildingproducts20oz4x10plainroundcopperdownspout',
#  'georgiapacific58x46x12toughrockfireguardtegypsumboard',
#  'bergerbuildingproducts032x156kstandardpaintedaluminumguttercoilroyalbrown',
#  'certainteedroofing4x4x8flintboardiso',
#  'gaf144x8densdeckroofboard',
#  'hunterpanels15x4x8xcifoilfacerpolyisoinsulation',
#  'weatherbondaa05to1taperedgradeii20psipolyisoinsulation',
#  ...]

# %%
total_unique_categories = len(set(categories))
print(total_unique_categories)
# Out:
# 4

# %%
data = {"Category": categories, "Sub-Category": subtypes, "Product": fileid, "Filename": filenames}
df = pd.DataFrame(data)

# %%
df
# Out:
#             Category                    Sub-Category  \
# 0            roofing           commercial-insulation
# 1      waterproofing        plaza-deck-waterproofing
# 2            roofing           commercial-insulation
# 3      waterproofing              air-vapor-barriers
# 4            gutters              gutter-accessories
# ...              ...                             ...
# 25048  waterproofing  below-grade-membranes-coatings
# 25049        roofing           commercial-insulation
# 25050        roofing           commercial-insulation
# 25051        gutters              gutter-accessories
# 25052     insulation           fiberglass-insulation
#
#                                                  Product  \
# 0                atlasroofing17x4x8polyisoroofinsulation
# 1                basfmastersealsl2slopegrade15gallonpail
# 2      hunterpanels175x4x8hshieldgradeii20psipolyisoi...
# 3      certainteedvinylbuildingproducts412x200certawr...
# 4           qualityedge019x2x3x4brickledgejumperwhite280
# ...                                                  ...
# 25048               cetcoakwaswellswellingpaste105oztube
# 25049  hunterpanels31x4x8hshieldgradeii20psipolyisoin...
# 25050               dowfrothpak620foamsealantkitwithhose
# 25051  bergerbuildingproducts18oz3110euracraftcoppers...
# 25052     owenscorning1x4x8selectsoundblackacousticboard
#
#                                                 Filename
# 0      roofing_commercial-insulation_atlasroofing17x4...
# 1      waterproofing_plaza-deck-waterproofing_basfmas...
# 2      roofing_commercial-insulation_hunterpanels175x...
# 3      waterproofing_air-vapor-barriers_certainteedvi...
# 4      gutters_gutter-accessories_qualityedge019x2x3x...
# ...                                                  ...
# 25048  waterproofing_below-grade-membranes-coatings_c...
# 25049  roofing_commercial-insulation_hunterpanels31x4...
# 25050  roofing_commercial-insulation_dowfrothpak620fo...
# 25051  gutters_gutter-accessories_bergerbuildingprodu...
# 25052  insulation_fiberglass-insulation_owenscorning1...
#
# [25053 rows x 4 columns]

# %%
roofing_subtypes = df[df["Category"] == "roofing"]["Sub-Category"].unique()
len(set(roofing_subtypes))
# Out:
# 1

# %%
df.to_csv('categories_filenames.csv', index=False)

# %%
# Load data from the CSV file
data = pd.read_csv('/home/sklaptop/Downloads/Proxzar-CV-work/Proxzar/categories_filenames.csv')

df = pd.DataFrame(data)

# %%
category_counts = df['Category'].value_counts()
print(category_counts)
# Out:
# Category
# gutters          10104
# roofing           6105
# waterproofing     4524
# insulation        4320
# Name: count, dtype: int64
